# %%
import asyncio

from agent_framework import TextReasoningContent
from agent_framework.ollama import OllamaChatClient

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
agent = OllamaChatClient(model_id=os.getenv("OLLAMA_CHAT_MODEL_ID")).as_agent(
        name="ReasoningAgent",
        instructions="You are my math teacher. Help the student solve the problems step by step.",
        additional_chat_options={"think": True},  # Enable Reasoning on agent level
)

# %%
query = "解释一下什么是勾股定理"

# %%
result = await agent.run(query)

# %%
reasoning = "".join((c.text or "") for c in result.messages[-1].contents if isinstance(c, TextReasoningContent))

# %%
reasoning
# Out:
# '嗯，用户让我解释勾股定理，作为数学老师，我需要先确定他们的理解程度。可能他们刚开始学几何，或者对基本概念不太清楚。首先，我应该从最基础的定义开始，用简单明了的语言。勾股定理是直角三角形的三边关系，所以得先明确直角三角形的结构，直角边和斜边的区别。\n\n接下来，可能需要举一个例子，比如3-4-5的三角形，这样更直观。不过用户可能需要更详细的步骤，比如如何推导这个定理。虽然用户没有明确要求推导过程，但作为老师，我应该考虑是否需要加入，或者是否应该先解释定理，再深入。\n\n还要注意用户可能的误区，比如混淆直角边和斜边，或者误以为所有三角形都适用。这时候需要强调定理的适用范围是直角三角形，其他类型的三角形不适用。另外，可能需要提到毕达哥拉斯定理的来源，或者历史背景，增加趣味性。\n\n另外，用户可能希望了解如何应用这个定理，比如计算未知边长。这时候可以给出一个实际的例子，比如已知两条直角边求斜边，或者已知斜边和一条直角边求另一条。同时，提醒他们注意单位和单位换算，可能用户在实际应用中会遇到这种情况。\n\n还要检查是否有常见的错误，比如把公式记错，比如a² + b² = c²，而不是其他形式。或者是否混淆了加减号。这时候需要强调公式的正确性，并通过练习题巩固记忆。\n\n最后，是否需要提供练习题或进一步的问题？用户可能希望有互动，所以可以建议他们尝试一些例子，或者提出相关问题，比如如果直角边分别是5和12，斜边是多少，这样他们可以应用所学知识。同时，提醒他们如果有疑问可以继续提问，保持开放的沟通。\n'

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Declinare de responsabilitate**:
# Acest document a fost tradus folosind serviciul de traducere AI [Co-op Translator](https://github.com/Azure/co-op-translator). Deși ne străduim pentru acuratețe, vă rugăm să rețineți că traducerile automate pot conține erori sau inexactități. Documentul original în limba sa nativă trebuie considerat sursa autoritară. Pentru informații critice, se recomandă traducerea profesională realizată de un traducător uman. Nu ne asumăm responsabilitatea pentru eventuale neînțelegeri sau interpretări greșite rezultate din utilizarea acestei traduceri.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
